# %%
# !pip install gradio

# %%
import gradio as gr

# %%
def greet(name):
    return "Hello " + name + "; welcome"


demo = gr.Interface(fn=greet, inputs="text", outputs="text")

demo.launch()

# %%
# We instantiate the Textbox class
#textbox = gr.Textbox(label="Type your name here:", placeholder="John Doe", lines=2)

#gr.Interface(fn=greet, inputs=textbox, outputs="text").launch()

# %%
from transformers import pipeline

model = pipeline("text-generation")
# Out:
# 2024-05-12 18:57:13.054708: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-12 18:57:13.054845: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-12 18:57:13.212285: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# No model was supplied, defaulted to openai-community/gpt2 and revision 6c0e608 (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
def predict(prompt):
    completion = model(prompt)[0]["generated_text"]
    return completion

# %%
predict("My favorite programming language is")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "My favorite programming language is C, but it's also the best programming language that I've ever used. I didn't realize how much I really love programming programming until I started learning C. I'm sure you can have a lot to say about C"

# %%
gr.Interface(fn=predict, inputs="text", outputs="text").launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Kaggle notebooks require sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Running on public URL: https://6cff564d4f803c08f4.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6cff564d4f803c08f4.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
